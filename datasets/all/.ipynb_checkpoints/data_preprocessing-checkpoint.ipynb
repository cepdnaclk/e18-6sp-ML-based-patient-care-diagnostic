# %%
import pandas as pd
import numpy as np

# %%
all_disease = pd.read_csv('dataset.csv')
all_disease
# Out:
#                      disease  \
# 0                        flu
# 1                 bronchitis
# 2                  pneumonia
# 3               heart attack
# 4                     stroke
# ..                       ...
# 94                 epilepsy
# 95              fibromyalgia
# 96           graves' disease
# 97  hashimoto's thyroiditis
# 98                     lupus
#
#                                              symptoms  \
# 0   fever,cough,sore throat,runny or stuffy nose,m...
# 1   cough,mucus production,shortness of breath,che...
# 2   fever,cough,shortness of breath,chest pain,fat...
# 3   chest pain,shortness of breath,nausea,vomiting...
# 4   sudden weakness,numbness on one side of the bo...
# ..                                                ...
# 94                                           seizures
# 95                 widespread pain,fatigue,tenderness
# 96     hyperthyroidism,which is an overactive thyroid
# 97    hypothyroidism,which is an underactive thyroid
# 98  chronic autoimmune disease that can affect any...
#
#                                                 cures  \
# 0            over-the-counter medications,rest,fluids
# 1   antibiotics,over-the-counter medications,rest,...
# 2   antibiotics,over-the-counter medications,rest,...
# 3                          emergency medical services
# 4                          emergency medical services
# ..                                                ...
# 94                                 medication,surgery
# 95                       medication,lifestyle changes
# 96                                 medication,surgery
# 97                                         medication
# 98                       medication,lifestyle changes
#
#                          doctor     risk level
# 0     family doctor,urgent care      low (0.1%
# 1   family doctor,pulmonologist      low (0.5%
# 2   family doctor,pulmonologist  moderate (1%)
# 3                  cardiologist     high (20%)
# 4                  neurologist      high (15%)
# ..                          ...            ...
# 94                  neurologist         varies
# 95               rheumatologist         varies
# 96              endocrinologist         varies
# 97              endocrinologist         varies
# 98              rheumatologist          varies
#
# [99 rows x 5 columns]

# %%
symptoms = all_disease['symptoms']

symptoms_array= []
symptoms_array_unique=[]
symptoms_array_final=[]


for i in range(symptoms.size):
    x = symptoms[i].split(',')
    for j in range(len(x)):
        symptoms_array.append(x[j])

for i in range(len(symptoms_array)):
    if not ((symptoms_array[i] in symptoms_array_unique)):
        symptoms_array_unique.append(symptoms_array[i])
            
for i in range(len(symptoms_array_unique)):
    x = symptoms_array_unique[i].split(' ')
    string = symptoms_array_unique[i]
    if(len(x)>1):
        string = ""
        for j in range(len(x)):
            string = string+x[j]
            string = string + '_'    
        string = string[:-1]
    
    symptoms_array_final.append(string)

with open("output.txt", "w") as txt_file:
    for line in symptoms_array_final:
        txt_file.write("".join(line) + "\n") # works with any number of elements in a line
        
symptoms_array_final.append('disease')
symptoms_array_final.append('cures')
symptoms_array_final.append('doctor')

symptoms_array_final
# Out:
# ['fever',
#  'cough',
#  'sore_throat',
#  'runny_or_stuffy_nose',
#  'muscle_aches',
#  'headache',
#  'fatigue',
#  'mucus_production',
#  'shortness_of_breath',
#  'chest_pain',
#  'nausea',
#  'vomiting',
#  'lightheadedness',
#  'sweating',
#  'sudden_weakness',
#  'numbness_on_one_side_of_the_body',
#  'confusion',
#  'difficulty_speaking',
#  'trouble_seeing_in_one_eye',
#  'severe_headache',
#  'lump',
#  'unexplained_weight_loss',
#  'changes_in_bowel',
#  'bladder_habits',
#  'persistent_cough',
#  'indigestion',
#  'unexplained_bleeding_or_discharge',
#  'increased_thirst',
#  'frequent_urination',
#  'blurred_vision',
#  'cuts_that_are_slow_to_heal',
#  'memory_loss',
#  'difficulty_thinking',
#  'changes_in_personality_or_behavior',
#  'pain',
#  'stiffness',
#  'swelling',
#  'inflammation_in_the_joints',
#  'conjunctivitis',
#  'rash',
#  'pink_eye',
#  'diarrhea',
#  'jaundice',
#  'liver_damage',
#  'death',
#  'physical_dependence_on_alcohol',
#  'tolerance_to_alcohol',
#  'withdrawal_symptoms',
#  'impaired_judgment',
#  'memory_problems',
#  'heart_disease',
#  'cancer',
#  'runny_nose',
#  'sneezing',
#  'itchy_eyes',
#  'itchy_nose',
#  'throat',
#  'palate',
#  'pale_skin',
#  'dizziness',
#  'excessive_worry',
#  'fear',
#  'anxiety_that_interfere_with_daily_life',
#  'pain_in_the_lower_right_abdomen',
#  'difficulty_with_social_interaction',
#  'repetitive_behaviors',
#  'restricted_interests',
#  'wheezing',
#  'coughing',
#  'chest_tightness',
#  'stiff_neck',
#  'sensitivity_to_light',
#  'extreme_mood_swings',
#  'from_manito_depression',
#  'blood_in_the_urine',
#  'pain_or_burning_when_urinating',
#  'urgency_to_urinate',
#  'incontinence',
#  'redness',
#  'warmth',
#  'tenderness_in_the_affected_area',
#  'difficulty_breathing',
#  'coughing_up_blood',
#  'inflammation_in_bursa',
#  'which_is_small_sac_of_fluid_that_cushions_joints',
#  'abnormal_pap_test_results',
#  'abnormal_vaginal_bleeding',
#  'pain_during_sex',
#  'chronic_bronchitis',
#  'emphysema',
#  'high_levels_of_cholesterol_in_the_blood',
#  'congestion',
#  'red',
#  'itchy',
#  'watery_eyes',
#  'sadness',
#  'hopelessness',
#  'loss_of_interest_in_activities',
#  'changes_in_appetite',
#  'sleep',
#  'energy_levels',
#  'loose',
#  'watery_stools',
#  'disturbance_in_eating_behavior_that_can_lead_to_serious_health_problems',
#  'seizures',
#  'elevated_body_temperature_',
#  'abdominal_cramps',
#  'pain_in_the_upper_right_abdomen',
#  'sexually_transmitted_infection_that_can_cause_burning_during_urination',
#  'discharge_from_the_penis_or_vagina',
#  'pain_in_the_lower_abdomen',
#  'fainting',
#  'inflammation_of_the_liver',
#  'sexually_transmitted_infection_that_can_cause_blisters_on_the_genitals',
#  'mouth',
#  'other_parts_of_the_body',
#  'abdominal_pain',
#  'bloating',
#  'constipation',
#  'pain_in_the_lower_back_or_side',
#  'cough_that_does_not_go_away',
#  'blood_in_the_sputum',
#  'chills',
#  'red_eyes',
#  'swollen_lymph_nodes',
#  'tingling_at_the_bite_site',
#  'difficulty_swallowing',
#  'hydrophobia',
#  'aerophobia',
#  'painful_rash_that_follows_nerve_path',
#  'night_sweats',
#  'weight_loss',
#  'painful_urination',
#  'burning',
#  'swollen',
#  'twisted_veins',
#  'usually_in_the_legs',
#  'raised',
#  'rough_growths_on_the_skin',
#  'itching',
#  'discharge_from_the_vaginor_penis',
#  'inflammation_in_the_eye',
#  'decreased_kidney_function',
#  'bulge_in_the_wall_of_the_aorta',
#  'the_largest_artery_in_the_body',
#  'change_in_bowel_habits',
#  'such_as_diarrhea',
#  'narrowing_of_the_stool',
#  'blood_in_the_stool',
#  'difficulty_getting',
#  'keeping_an_erection_',
#  'widespread_pain',
#  'tenderness',
#  'increased_pressure_in_the_eye_that_can_damage_the_optic_nerve',
#  'lead_to_vision_loss',
#  'condition_in_which_the_heart_cannot_pump_blood_as_well_as_it_should',
#  'damage_to_the_kidneys_that_can_lead_to_kidney_failure',
#  'condition_that_affects_the_lungs',
#  'can_make_it_difficult_to_breathe',
#  'tremors',
#  'slow_movement',
#  'difficulty_with_balance',
#  'coordination_',
#  'pain_in_the_upper_abdomen',
#  'numbness',
#  'tingling_in_the_arms_or_legs',
#  'difficulty_urinating',
#  'pain_in_the_back_or_hips',
#  'erectile_dysfunction',
#  'stiffness_in_the_joints',
#  'lump_in_the_neck',
#  'hoarseness',
#  'unexplained_heat_intolerance',
#  'sensitivity_to_cold',
#  'bloody_stool',
#  'inflamed_skin',
#  'high_blood_pressure',
#  'changes_in_urination',
#  'hyperthyroidism',
#  'which_is_an_overactive_thyroid',
#  'hypothyroidism',
#  'which_is_an_underactive_thyroid_',
#  'chronic_autoimmune_disease_that_can_affect_any_part_of_the_body',
#  'disease',
#  'cures',
#  'doctor']

# %%
df = pd.DataFrame(columns=symptoms_array_final)
df.to_csv('formatted_dataset.csv')

row2 = np.array([])

for i in range(all_disease.shape[0]):
    row = all_disease.iloc[i].to_numpy()
    row3 = row[1].split(',');
    row2 = []
    
    for j in range(len(symptoms_array_unique)):
        if(symptoms_array_unique[j] in row3):
            row2.append(1)
        else:
            row2.append(0)
    
    row2.append(row[0])
    row2.append(row[2])
    row2.append(row[3])

    df.loc[len(df.index)] = row2 

df.to_csv('formatted_dataset.csv')
# Out:
# over-the-counter medications,rest,fluids
# antibiotics,over-the-counter medications,rest,fluids
# antibiotics,over-the-counter medications,rest,fluids
# emergency medical services
# emergency medical services
# surgery,chemotherapy,radiation therapy
# diet,exercise,medication
# there is no cure for alzheimer's disease,but there are treatments that can help manage the symptoms
# medication,physical therapy,lifestyle changes
# antibiotics,over-the-counter medications,rest,fluids
# there is no cure for aflatoxicosis,but treatment may include supportive care,liver transplantation
#  treatment for alcoholism may include counseling,medication,support groups
# over-the-counter medications,allergy shots
# there is no cure for alzheimer's disease,but there are treatments that can help manage the symptoms
#
# treatment for anxiety disorders may include therapy,medication,combination of both
# appendectomy
# medication,physical therapy,lifestyle changes
# there is no cure for asperger syndrome,but there are treatments that can help manage the symptoms
# treatment for asthmmay include medication,lifestyle changes,allergy shots
# antibiotics
# treatment for bipolar disorder may include medication,therapy,combination of both
# surgery,chemotherapy,radiation therapy
# treatment for blood clot may include medication,surgery,combination of both
# antibiotics,over-the-counter medications,rest,fluids
# medication,rest,ice,compression,elevation
# surgery,chemotherapy,radiation therapy
# surgery,chemotherapy,radiation therapy
# antiviral medication,over-the-counter medications,rest,fluids
# treatment for copd may include medication,lifestyle changes,oxygen therapy
# diet,exercise,medication
# over-the-counter medications,rest,fluids
# over-the-counter medications,warm compresses
# treatment for depression may include medication,therapy,combination of both
# diet,exercise,medication
# over-the-counter medications,rest,fluids
# treatment for eating disorders may include therapy,medication,support groups
# medication,surgery
# over-the-counter medications,rest,fluids
# over-the-counter medications,rest,fluids
# surgery
# antibiotics
# treatment for heart disease may include medication,lifestyle changes,surgery
# treatment for hepatitis may include medication,rest,lifestyle changes
# there is no cure for herpes,but there are treatments that can help manage the symptoms
# over-the-counter medications,rest,fluids
# treatment for ibs may include diet,lifestyle changes,medication
# surgery
# surgery,chemotherapy,radiation therapy
# antimalarial drugs
# measles vaccine
# antibiotics
# there is no cure for mononucleosis,but symptoms can be treated with rest,fluids,over-the-counter medications
# antibiotics
# rabies vaccine
# antibiotics
# antiviral medication
# antibiotics
# antibiotics
# surgery,compression stockings,lifestyle changes
# over-the-counter medications,prescription medications,cryotherapy,laser therapy
# over-the-counter medications,prescription medications
# antibiotics,antifungals,surgery
# appendectomy
# treatment for the underlying cause,such as dehydration,infection,medication side effect
# there is no cure for alzheimer's disease,but there are treatments that can help manage the symptoms
# treatment for anemidepends on the type of anemia,but may include medication,blood transfusions,surgery
# surgery
# antibiotics
# treatment for bipolar disorder may include medication,therapy,combination of both
# surgery,chemotherapy,radiation therapy
# surgery,chemotherapy,radiation therapy
# there is no cure for dementia,but there are treatments that can help manage the symptoms
# medication,lifestyle changes,surgery
# medication,lifestyle changes
# medication,surgery
# medication,lifestyle changes,surgery
# treatment for the underlying cause,such as high blood pressure,diabetes,an infection
# treatment for the underlying cause,such as asthma,chronic obstructive pulmonary disease (copd),pneumonia
#  medication,lifestyle changes
# medication,lifestyle changes,surgery
# medication,lifestyle changes,surgery
# antibiotics
#  surgery,radiation therapy,hormone therapy
# medication,lifestyle changes
# treatment for the underlying cause,such as clot-busting medication,surgery
# surgery,chemotherapy,radiation therapy
# surgery,radiation therapy,hormone therapy
# medication,surgery
# over-the-counter medications,prescription medications,cryotherapy,laser therapy
# medication,lifestyle changes
# gluten-free diet
# treatment for the underlying cause,such as high blood pressure,diabetes,an infection
# medication,surgery
# medication,surgery
# medication,lifestyle changes
# medication,surgery
# medication
# medication,lifestyle changes
